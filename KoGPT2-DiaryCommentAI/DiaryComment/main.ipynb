# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 폴더 이동
# %cd /content/drive/MyDrive/Colab Notebooks/KoGPT2-DiaryCommentAI/DiaryComment
# Out:
# /content/drive/MyDrive/Colab Notebooks/KoGPT2-DiaryCommentAI/DiaryComment

# %%
# !pip install -r requirements.txt
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# 사전훈련된 KoGPT2를 챗봇 데이터로 파인튜닝
# !CUDA_VISIBLE_DEVICES=0 python KoGPT2.py --train --gpus 1 --max_epochs 10

# %%
# 대화 테스트, `quit`를 입력하면 대화를 종료합니다.
# !CUDA_VISIBLE_DEVICES=0 python KoGPT2.py --gpus 1 --comment
